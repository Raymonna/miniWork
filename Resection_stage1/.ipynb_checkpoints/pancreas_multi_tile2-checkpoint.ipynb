# %%
import os
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
gpu_options = tf.GPUOptions(allow_growth=True)
sess_config = tf.ConfigProto(gpu_options=gpu_options)
tf.keras.backend.set_session(tf.Session(config=sess_config))

# %%
import os
import glob
#import tqdm
import numpy as np
#import pandas as pd
import multiprocessing
import pydicom as dicom
import nibabel as nib
#from keras import utils as kutils
from matplotlib import pyplot as plt

def load_image(label_fpath, transpose=False):
    #encode_name = label_fpath[-39: -7]
    label_data = nib.load(label_fpath)
    label_array = label_data.get_fdata()
    if transpose:
        label_array = np.transpose(label_array, axes=(2, 1, 0))
    return  label_array#, encode_name

# %%
import pandas as pd
info = pd.read_csv('/data2/pancreas/Nifti_data/data_list.csv')
image_path = "/data2/pancreas/Nifti_data/image"
label_path = "/data2/pancreas/Nifti_data/label"

shape = np.load("shape.npz.npy")
resec = np.load("resec.npy")
y = np.load("resec_y.npy")

# %%
#100:400 200:360 
#60:5, 40:4, +-20 median   24 inouts 
def clip_img(r, img):# make image to be in shape of (360, 300, 110)
    img_tmp = np.zeros((360, 300, 110))
    img_tmp[:int(r[1]-r[0]), :int(r[3]-r[2]), :int(r[5]-r[4])] = img[int(r[0]):int(r[1]), int(r[2]):int(r[3]), int(r[4]):int(r[5])]
    return img_tmp
    
def extract_cube(img, i):#Input((60, 50, 55, 1)) ; the i-th cube   6*6*2
    j = i%6
    k = i%6
    l = i%2
    #print(img[j*60:(j+1)*60, k*40:(1+k)*40, l*30:(l+1)*30].shape)
    return img[j*60:(j+1)*60, k*50:(1+k)*50, l*55:(l+1)*55]

# %%
# #New
# def extract_cube(r, img):#cube 360, 300, 110 ;; ranges = [xmin, xmax, ymin, ymax, zmin, zmax]
#     img_tmp = np.zeros((360, 300, 110))
#     img_tmp[:int(r[1]-r[0]), :int(r[3]-r[2]), :int(r[5]-r[4])] = img[int(r[0]):int(r[1]), int(r[2]):int(r[3]), int(r[4]):int(r[5])]
#     return img_tmp

# %%
import pandas as pd
map_df = pd.DataFrame(data={'resec_name': resec, 'shape': np.array(range(182)), 'target':y.reshape(182)})

# %%
from keras.utils import to_categorical

class resec_Generator(kutils.Sequence):
    'Generates data for Keras'
    def __init__(self, mapping_df, batch_size, shuffle=True):
        'Initialization'
        self.mapping_df = mapping_df
        self.data_num   = mapping_df.shape[0]
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(self.data_num / self.batch_size))


    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        #print("enter0")
        batch_mapping_df = \
            self.mapping_df.iloc[index*self.batch_size: (index+1)*self.batch_size]

        # Generate data
        X, y = self.__data_generation(batch_mapping_df)
        return X, y


    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            self.mapping_df = self.mapping_df.sample(frac=1).reset_index(drop=True)
            
    def __data_generation(self, batch_mapping_df):
        'Generates data containing batch_size samples' 
        # Initialization
        X = [np.zeros((self.batch_size, 60, 50, 55, 1)) for i in range(72)]
        y = np.zeros((self.batch_size))

        # Generate data
        cnt = 0
        
        for i, row in batch_mapping_df.iterrows():
            img = clip_img(shape[row['shape']], load_image(os.path.join(image_path, "IM_"+row['resec_name']+".nii.gz")))
            for j in range(72):
                
                X[j][cnt, :, :, :, 0] = extract_cube(img, j)
            y[cnt] = row['target']
            cnt += 1
        return X, y

# %%
from keras.models import Model#, load_model
from keras import layers as klayers
from keras.optimizers import Adam
from keras import utils as kutils
from keras import backend as K
from keras.callbacks import ModelCheckpoint



from keras.layers import Conv3D, MaxPool3D, Flatten, Dense
from keras.layers import Dropout, Input, BatchNormalization
from sklearn.metrics import confusion_matrix, accuracy_score
#from plotly.offline import iplot, init_notebook_mode
from keras.losses import categorical_crossentropy
from keras.optimizers import Adadelta
#import plotly.graph_objs as go
from matplotlib.pyplot import cm
from keras.models import Model
import numpy as np
import keras
import h5py




from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, multiply, concatenate,  MaxPool2D
# from keras.layers import BatchNormalization, Activation, Embedding, ZeroPadding2D, Lambda
from keras.layers.advanced_activations import LeakyReLU, ReLU
from keras.layers.convolutional import UpSampling2D, Conv2D, Conv1D
from keras.models import Sequential, Model
from keras.optimizers import Adam, SGD
from keras.utils import to_categorical
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM, TimeDistributed, RepeatVector, Reshape
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
## input layer
from keras import metrics
xs = []
input_set = []
for i in range(72):
    tmp_x = Input((60, 50, 55, 1))
    input_set.append(tmp_x)
    x = Conv3D(filters=32, dilation_rate=1, kernel_size=(3, 3, 3), kernel_initializer=keras.initializers.glorot_normal(seed=None), activation='selu')(tmp_x)
    #x = BatchNormalization()(x)

    x = MaxPool3D()(x)

    x = Conv3D(filters=16, dilation_rate=1, kernel_size=(3, 3, 3),  activation='relu')(x)
    #x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = MaxPool3D()(x)

    x = Conv3D(filters=4, dilation_rate=1, kernel_size=(3, 3, 3), activation='relu')(x)
    #x = BatchNormalization()(x)
  
    x = MaxPool3D()(x)
    
    
    
    xs.append(x)
    
x = xs[0]
for i in range(1, 72):
    x = concatenate([x, xs[i]], axis = 4)
    

x = MaxPool3D()(x)
x = Conv3D(filters=32, dilation_rate=1, kernel_size=(1, 1, 1), kernel_initializer=keras.initializers.glorot_normal(seed=None), activation='selu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)

x = Conv3D(filters=4, dilation_rate=1, kernel_size=(1, 1, 1), activation='selu')(x)
x = BatchNormalization()(x)







x = Flatten()(x)

x = Dense(units=100, kernel_initializer='normal', activation='relu')(x)
x = Dropout(0.3)(x)
#x = Dense(units=100, kernel_initializer='normal', activation='relu')(x)

x = Dense(units=50, kernel_initializer='normal', activation='selu')(x)
x = Dense(units=1, kernel_initializer='normal', activation='sigmoid')(x)


model = Model(inputs=input_set, outputs=x)
adam_lr = 0.0002
adam_beta_1 = 0.5
model.compile(optimizer=Adam(lr=adam_lr, beta_1=adam_beta_1),
              loss='binary_crossentropy', metrics = [metrics.binary_accuracy])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_217 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# input_218 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# conv3d_655 (Conv3D)             (None, 58, 48, 53, 3 896         input_217[0][0]
# __________________________________________________________________________________________________
# conv3d_658 (Conv3D)             (None, 58, 48, 53, 3 896         input_218[0][0]
# __________________________________________________________________________________________________
# input_219 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# max_pooling3d_652 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_655[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_655 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_658[0][0]
# __________________________________________________________________________________________________
# conv3d_661 (Conv3D)             (None, 58, 48, 53, 3 896         input_219[0][0]
# __________________________________________________________________________________________________
# input_220 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# conv3d_656 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_652[0][0]
# __________________________________________________________________________________________________
# conv3d_659 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_655[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_658 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_661[0][0]
# __________________________________________________________________________________________________
# conv3d_664 (Conv3D)             (None, 58, 48, 53, 3 896         input_220[0][0]
# __________________________________________________________________________________________________
# input_221 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# dropout_223 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_656[0][0]
# __________________________________________________________________________________________________
# dropout_224 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_659[0][0]
# __________________________________________________________________________________________________
# conv3d_662 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_658[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_661 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_664[0][0]
# __________________________________________________________________________________________________
# conv3d_667 (Conv3D)             (None, 58, 48, 53, 3 896         input_221[0][0]
# __________________________________________________________________________________________________
# input_222 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# max_pooling3d_653 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_223[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_656 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_224[0][0]
# __________________________________________________________________________________________________
# dropout_225 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_662[0][0]
# __________________________________________________________________________________________________
# conv3d_665 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_661[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_664 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_667[0][0]
# __________________________________________________________________________________________________
# conv3d_670 (Conv3D)             (None, 58, 48, 53, 3 896         input_222[0][0]
# __________________________________________________________________________________________________
# input_223 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# conv3d_657 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_653[0][0]
# __________________________________________________________________________________________________
# conv3d_660 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_656[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_659 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_225[0][0]
# __________________________________________________________________________________________________
# dropout_226 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_665[0][0]
# __________________________________________________________________________________________________
# conv3d_668 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_664[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_667 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_670[0][0]
# __________________________________________________________________________________________________
# conv3d_673 (Conv3D)             (None, 58, 48, 53, 3 896         input_223[0][0]
# __________________________________________________________________________________________________
# input_224 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# max_pooling3d_654 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_657[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_657 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_660[0][0]
# __________________________________________________________________________________________________
# conv3d_663 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_659[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_662 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_226[0][0]
# __________________________________________________________________________________________________
# dropout_227 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_668[0][0]
# __________________________________________________________________________________________________
# conv3d_671 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_667[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_670 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_673[0][0]
# __________________________________________________________________________________________________
# conv3d_676 (Conv3D)             (None, 58, 48, 53, 3 896         input_224[0][0]
# __________________________________________________________________________________________________
# input_225 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_214 (Concatenate)   (None, 5, 4, 5, 8)   0           max_pooling3d_654[0][0]
#                                                                  max_pooling3d_657[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_660 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_663[0][0]
# __________________________________________________________________________________________________
# conv3d_666 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_662[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_665 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_227[0][0]
# __________________________________________________________________________________________________
# dropout_228 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_671[0][0]
# __________________________________________________________________________________________________
# conv3d_674 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_670[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_673 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_676[0][0]
# __________________________________________________________________________________________________
# conv3d_679 (Conv3D)             (None, 58, 48, 53, 3 896         input_225[0][0]
# __________________________________________________________________________________________________
# input_226 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_215 (Concatenate)   (None, 5, 4, 5, 12)  0           concatenate_214[0][0]
#                                                                  max_pooling3d_660[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_663 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_666[0][0]
# __________________________________________________________________________________________________
# conv3d_669 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_665[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_668 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_228[0][0]
# __________________________________________________________________________________________________
# dropout_229 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_674[0][0]
# __________________________________________________________________________________________________
# conv3d_677 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_673[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_676 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_679[0][0]
# __________________________________________________________________________________________________
# conv3d_682 (Conv3D)             (None, 58, 48, 53, 3 896         input_226[0][0]
# __________________________________________________________________________________________________
# input_227 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_216 (Concatenate)   (None, 5, 4, 5, 16)  0           concatenate_215[0][0]
#                                                                  max_pooling3d_663[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_666 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_669[0][0]
# __________________________________________________________________________________________________
# conv3d_672 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_668[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_671 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_229[0][0]
# __________________________________________________________________________________________________
# dropout_230 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_677[0][0]
# __________________________________________________________________________________________________
# conv3d_680 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_676[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_679 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_682[0][0]
# __________________________________________________________________________________________________
# conv3d_685 (Conv3D)             (None, 58, 48, 53, 3 896         input_227[0][0]
# __________________________________________________________________________________________________
# input_228 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_217 (Concatenate)   (None, 5, 4, 5, 20)  0           concatenate_216[0][0]
#                                                                  max_pooling3d_666[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_669 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_672[0][0]
# __________________________________________________________________________________________________
# conv3d_675 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_671[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_674 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_230[0][0]
# __________________________________________________________________________________________________
# dropout_231 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_680[0][0]
# __________________________________________________________________________________________________
# conv3d_683 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_679[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_682 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_685[0][0]
# __________________________________________________________________________________________________
# conv3d_688 (Conv3D)             (None, 58, 48, 53, 3 896         input_228[0][0]
# __________________________________________________________________________________________________
# input_229 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_218 (Concatenate)   (None, 5, 4, 5, 24)  0           concatenate_217[0][0]
#                                                                  max_pooling3d_669[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_672 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_675[0][0]
# __________________________________________________________________________________________________
# conv3d_678 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_674[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_677 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_231[0][0]
# __________________________________________________________________________________________________
# dropout_232 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_683[0][0]
# __________________________________________________________________________________________________
# conv3d_686 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_682[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_685 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_688[0][0]
# __________________________________________________________________________________________________
# conv3d_691 (Conv3D)             (None, 58, 48, 53, 3 896         input_229[0][0]
# __________________________________________________________________________________________________
# input_230 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_219 (Concatenate)   (None, 5, 4, 5, 28)  0           concatenate_218[0][0]
#                                                                  max_pooling3d_672[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_675 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_678[0][0]
# __________________________________________________________________________________________________
# conv3d_681 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_677[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_680 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_232[0][0]
# __________________________________________________________________________________________________
# dropout_233 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_686[0][0]
# __________________________________________________________________________________________________
# conv3d_689 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_685[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_688 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_691[0][0]
# __________________________________________________________________________________________________
# conv3d_694 (Conv3D)             (None, 58, 48, 53, 3 896         input_230[0][0]
# __________________________________________________________________________________________________
# input_231 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_220 (Concatenate)   (None, 5, 4, 5, 32)  0           concatenate_219[0][0]
#                                                                  max_pooling3d_675[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_678 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_681[0][0]
# __________________________________________________________________________________________________
# conv3d_684 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_680[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_683 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_233[0][0]
# __________________________________________________________________________________________________
# dropout_234 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_689[0][0]
# __________________________________________________________________________________________________
# conv3d_692 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_688[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_691 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_694[0][0]
# __________________________________________________________________________________________________
# conv3d_697 (Conv3D)             (None, 58, 48, 53, 3 896         input_231[0][0]
# __________________________________________________________________________________________________
# input_232 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_221 (Concatenate)   (None, 5, 4, 5, 36)  0           concatenate_220[0][0]
#                                                                  max_pooling3d_678[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_681 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_684[0][0]
# __________________________________________________________________________________________________
# conv3d_687 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_683[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_686 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_234[0][0]
# __________________________________________________________________________________________________
# dropout_235 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_692[0][0]
# __________________________________________________________________________________________________
# conv3d_695 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_691[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_694 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_697[0][0]
# __________________________________________________________________________________________________
# conv3d_700 (Conv3D)             (None, 58, 48, 53, 3 896         input_232[0][0]
# __________________________________________________________________________________________________
# input_233 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_222 (Concatenate)   (None, 5, 4, 5, 40)  0           concatenate_221[0][0]
#                                                                  max_pooling3d_681[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_684 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_687[0][0]
# __________________________________________________________________________________________________
# conv3d_690 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_686[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_689 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_235[0][0]
# __________________________________________________________________________________________________
# dropout_236 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_695[0][0]
# __________________________________________________________________________________________________
# conv3d_698 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_694[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_697 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_700[0][0]
# __________________________________________________________________________________________________
# conv3d_703 (Conv3D)             (None, 58, 48, 53, 3 896         input_233[0][0]
# __________________________________________________________________________________________________
# input_234 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_223 (Concatenate)   (None, 5, 4, 5, 44)  0           concatenate_222[0][0]
#                                                                  max_pooling3d_684[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_687 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_690[0][0]
# __________________________________________________________________________________________________
# conv3d_693 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_689[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_692 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_236[0][0]
# __________________________________________________________________________________________________
# dropout_237 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_698[0][0]
# __________________________________________________________________________________________________
# conv3d_701 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_697[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_700 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_703[0][0]
# __________________________________________________________________________________________________
# conv3d_706 (Conv3D)             (None, 58, 48, 53, 3 896         input_234[0][0]
# __________________________________________________________________________________________________
# input_235 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_224 (Concatenate)   (None, 5, 4, 5, 48)  0           concatenate_223[0][0]
#                                                                  max_pooling3d_687[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_690 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_693[0][0]
# __________________________________________________________________________________________________
# conv3d_696 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_692[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_695 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_237[0][0]
# __________________________________________________________________________________________________
# dropout_238 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_701[0][0]
# __________________________________________________________________________________________________
# conv3d_704 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_700[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_703 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_706[0][0]
# __________________________________________________________________________________________________
# conv3d_709 (Conv3D)             (None, 58, 48, 53, 3 896         input_235[0][0]
# __________________________________________________________________________________________________
# input_236 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_225 (Concatenate)   (None, 5, 4, 5, 52)  0           concatenate_224[0][0]
#                                                                  max_pooling3d_690[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_693 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_696[0][0]
# __________________________________________________________________________________________________
# conv3d_699 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_695[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_698 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_238[0][0]
# __________________________________________________________________________________________________
# dropout_239 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_704[0][0]
# __________________________________________________________________________________________________
# conv3d_707 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_703[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_706 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_709[0][0]
# __________________________________________________________________________________________________
# conv3d_712 (Conv3D)             (None, 58, 48, 53, 3 896         input_236[0][0]
# __________________________________________________________________________________________________
# input_237 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_226 (Concatenate)   (None, 5, 4, 5, 56)  0           concatenate_225[0][0]
#                                                                  max_pooling3d_693[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_696 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_699[0][0]
# __________________________________________________________________________________________________
# conv3d_702 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_698[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_701 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_239[0][0]
# __________________________________________________________________________________________________
# dropout_240 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_707[0][0]
# __________________________________________________________________________________________________
# conv3d_710 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_706[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_709 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_712[0][0]
# __________________________________________________________________________________________________
# conv3d_715 (Conv3D)             (None, 58, 48, 53, 3 896         input_237[0][0]
# __________________________________________________________________________________________________
# input_238 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_227 (Concatenate)   (None, 5, 4, 5, 60)  0           concatenate_226[0][0]
#                                                                  max_pooling3d_696[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_699 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_702[0][0]
# __________________________________________________________________________________________________
# conv3d_705 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_701[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_704 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_240[0][0]
# __________________________________________________________________________________________________
# dropout_241 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_710[0][0]
# __________________________________________________________________________________________________
# conv3d_713 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_709[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_712 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_715[0][0]
# __________________________________________________________________________________________________
# conv3d_718 (Conv3D)             (None, 58, 48, 53, 3 896         input_238[0][0]
# __________________________________________________________________________________________________
# input_239 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_228 (Concatenate)   (None, 5, 4, 5, 64)  0           concatenate_227[0][0]
#                                                                  max_pooling3d_699[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_702 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_705[0][0]
# __________________________________________________________________________________________________
# conv3d_708 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_704[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_707 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_241[0][0]
# __________________________________________________________________________________________________
# dropout_242 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_713[0][0]
# __________________________________________________________________________________________________
# conv3d_716 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_712[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_715 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_718[0][0]
# __________________________________________________________________________________________________
# conv3d_721 (Conv3D)             (None, 58, 48, 53, 3 896         input_239[0][0]
# __________________________________________________________________________________________________
# input_240 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_229 (Concatenate)   (None, 5, 4, 5, 68)  0           concatenate_228[0][0]
#                                                                  max_pooling3d_702[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_705 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_708[0][0]
# __________________________________________________________________________________________________
# conv3d_711 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_707[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_710 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_242[0][0]
# __________________________________________________________________________________________________
# dropout_243 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_716[0][0]
# __________________________________________________________________________________________________
# conv3d_719 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_715[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_718 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_721[0][0]
# __________________________________________________________________________________________________
# conv3d_724 (Conv3D)             (None, 58, 48, 53, 3 896         input_240[0][0]
# __________________________________________________________________________________________________
# input_241 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_230 (Concatenate)   (None, 5, 4, 5, 72)  0           concatenate_229[0][0]
#                                                                  max_pooling3d_705[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_708 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_711[0][0]
# __________________________________________________________________________________________________
# conv3d_714 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_710[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_713 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_243[0][0]
# __________________________________________________________________________________________________
# dropout_244 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_719[0][0]
# __________________________________________________________________________________________________
# conv3d_722 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_718[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_721 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_724[0][0]
# __________________________________________________________________________________________________
# conv3d_727 (Conv3D)             (None, 58, 48, 53, 3 896         input_241[0][0]
# __________________________________________________________________________________________________
# input_242 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_231 (Concatenate)   (None, 5, 4, 5, 76)  0           concatenate_230[0][0]
#                                                                  max_pooling3d_708[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_711 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_714[0][0]
# __________________________________________________________________________________________________
# conv3d_717 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_713[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_716 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_244[0][0]
# __________________________________________________________________________________________________
# dropout_245 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_722[0][0]
# __________________________________________________________________________________________________
# conv3d_725 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_721[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_724 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_727[0][0]
# __________________________________________________________________________________________________
# conv3d_730 (Conv3D)             (None, 58, 48, 53, 3 896         input_242[0][0]
# __________________________________________________________________________________________________
# input_243 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_232 (Concatenate)   (None, 5, 4, 5, 80)  0           concatenate_231[0][0]
#                                                                  max_pooling3d_711[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_714 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_717[0][0]
# __________________________________________________________________________________________________
# conv3d_720 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_716[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_719 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_245[0][0]
# __________________________________________________________________________________________________
# dropout_246 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_725[0][0]
# __________________________________________________________________________________________________
# conv3d_728 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_724[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_727 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_730[0][0]
# __________________________________________________________________________________________________
# conv3d_733 (Conv3D)             (None, 58, 48, 53, 3 896         input_243[0][0]
# __________________________________________________________________________________________________
# input_244 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_233 (Concatenate)   (None, 5, 4, 5, 84)  0           concatenate_232[0][0]
#                                                                  max_pooling3d_714[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_717 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_720[0][0]
# __________________________________________________________________________________________________
# conv3d_723 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_719[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_722 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_246[0][0]
# __________________________________________________________________________________________________
# dropout_247 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_728[0][0]
# __________________________________________________________________________________________________
# conv3d_731 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_727[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_730 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_733[0][0]
# __________________________________________________________________________________________________
# conv3d_736 (Conv3D)             (None, 58, 48, 53, 3 896         input_244[0][0]
# __________________________________________________________________________________________________
# input_245 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_234 (Concatenate)   (None, 5, 4, 5, 88)  0           concatenate_233[0][0]
#                                                                  max_pooling3d_717[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_720 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_723[0][0]
# __________________________________________________________________________________________________
# conv3d_726 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_722[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_725 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_247[0][0]
# __________________________________________________________________________________________________
# dropout_248 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_731[0][0]
# __________________________________________________________________________________________________
# conv3d_734 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_730[0][0]
# __________________________________________________________________________________________________
# ...
# concatenate_274 (Concatenate)   (None, 5, 4, 5, 248) 0           concatenate_273[0][0]
#                                                                  max_pooling3d_837[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_840 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_843[0][0]
# __________________________________________________________________________________________________
# conv3d_846 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_842[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_845 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_287[0][0]
# __________________________________________________________________________________________________
# dropout_288 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_851[0][0]
# __________________________________________________________________________________________________
# conv3d_854 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_850[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_853 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_856[0][0]
# __________________________________________________________________________________________________
# conv3d_859 (Conv3D)             (None, 58, 48, 53, 3 896         input_285[0][0]
# __________________________________________________________________________________________________
# input_286 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_275 (Concatenate)   (None, 5, 4, 5, 252) 0           concatenate_274[0][0]
#                                                                  max_pooling3d_840[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_843 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_846[0][0]
# __________________________________________________________________________________________________
# conv3d_849 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_845[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_848 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_288[0][0]
# __________________________________________________________________________________________________
# dropout_289 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_854[0][0]
# __________________________________________________________________________________________________
# conv3d_857 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_853[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_856 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_859[0][0]
# __________________________________________________________________________________________________
# conv3d_862 (Conv3D)             (None, 58, 48, 53, 3 896         input_286[0][0]
# __________________________________________________________________________________________________
# input_287 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_276 (Concatenate)   (None, 5, 4, 5, 256) 0           concatenate_275[0][0]
#                                                                  max_pooling3d_843[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_846 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_849[0][0]
# __________________________________________________________________________________________________
# conv3d_852 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_848[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_851 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_289[0][0]
# __________________________________________________________________________________________________
# dropout_290 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_857[0][0]
# __________________________________________________________________________________________________
# conv3d_860 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_856[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_859 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_862[0][0]
# __________________________________________________________________________________________________
# conv3d_865 (Conv3D)             (None, 58, 48, 53, 3 896         input_287[0][0]
# __________________________________________________________________________________________________
# input_288 (InputLayer)          (None, 60, 50, 55, 1 0
# __________________________________________________________________________________________________
# concatenate_277 (Concatenate)   (None, 5, 4, 5, 260) 0           concatenate_276[0][0]
#                                                                  max_pooling3d_846[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_849 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_852[0][0]
# __________________________________________________________________________________________________
# conv3d_855 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_851[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_854 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_290[0][0]
# __________________________________________________________________________________________________
# dropout_291 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_860[0][0]
# __________________________________________________________________________________________________
# conv3d_863 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_859[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_862 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_865[0][0]
# __________________________________________________________________________________________________
# conv3d_868 (Conv3D)             (None, 58, 48, 53, 3 896         input_288[0][0]
# __________________________________________________________________________________________________
# concatenate_278 (Concatenate)   (None, 5, 4, 5, 264) 0           concatenate_277[0][0]
#                                                                  max_pooling3d_849[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_852 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_855[0][0]
# __________________________________________________________________________________________________
# conv3d_858 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_854[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_857 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_291[0][0]
# __________________________________________________________________________________________________
# dropout_292 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_863[0][0]
# __________________________________________________________________________________________________
# conv3d_866 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_862[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_865 (MaxPooling3D (None, 29, 24, 26, 3 0           conv3d_868[0][0]
# __________________________________________________________________________________________________
# concatenate_279 (Concatenate)   (None, 5, 4, 5, 268) 0           concatenate_278[0][0]
#                                                                  max_pooling3d_852[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_855 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_858[0][0]
# __________________________________________________________________________________________________
# conv3d_861 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_857[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_860 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_292[0][0]
# __________________________________________________________________________________________________
# dropout_293 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_866[0][0]
# __________________________________________________________________________________________________
# conv3d_869 (Conv3D)             (None, 27, 22, 24, 1 13840       max_pooling3d_865[0][0]
# __________________________________________________________________________________________________
# concatenate_280 (Concatenate)   (None, 5, 4, 5, 272) 0           concatenate_279[0][0]
#                                                                  max_pooling3d_855[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_858 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_861[0][0]
# __________________________________________________________________________________________________
# conv3d_864 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_860[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_863 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_293[0][0]
# __________________________________________________________________________________________________
# dropout_294 (Dropout)           (None, 27, 22, 24, 1 0           conv3d_869[0][0]
# __________________________________________________________________________________________________
# concatenate_281 (Concatenate)   (None, 5, 4, 5, 276) 0           concatenate_280[0][0]
#                                                                  max_pooling3d_858[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_861 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_864[0][0]
# __________________________________________________________________________________________________
# conv3d_867 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_863[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_866 (MaxPooling3D (None, 13, 11, 12, 1 0           dropout_294[0][0]
# __________________________________________________________________________________________________
# concatenate_282 (Concatenate)   (None, 5, 4, 5, 280) 0           concatenate_281[0][0]
#                                                                  max_pooling3d_861[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_864 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_867[0][0]
# __________________________________________________________________________________________________
# conv3d_870 (Conv3D)             (None, 11, 9, 10, 4) 1732        max_pooling3d_866[0][0]
# __________________________________________________________________________________________________
# concatenate_283 (Concatenate)   (None, 5, 4, 5, 284) 0           concatenate_282[0][0]
#                                                                  max_pooling3d_864[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_867 (MaxPooling3D (None, 5, 4, 5, 4)   0           conv3d_870[0][0]
# __________________________________________________________________________________________________
# concatenate_284 (Concatenate)   (None, 5, 4, 5, 288) 0           concatenate_283[0][0]
#                                                                  max_pooling3d_867[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_868 (MaxPooling3D (None, 2, 2, 2, 288) 0           concatenate_284[0][0]
# __________________________________________________________________________________________________
# conv3d_871 (Conv3D)             (None, 2, 2, 2, 32)  9248        max_pooling3d_868[0][0]
# __________________________________________________________________________________________________
# dropout_295 (Dropout)           (None, 2, 2, 2, 32)  0           conv3d_871[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2, 2, 2, 32)  128         dropout_295[0][0]
# __________________________________________________________________________________________________
# conv3d_872 (Conv3D)             (None, 2, 2, 2, 4)   132         batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 2, 2, 2, 4)   16          conv3d_872[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 32)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 100)          3300        flatten_4[0][0]
# __________________________________________________________________________________________________
# dropout_296 (Dropout)           (None, 100)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 50)           5050        dropout_296[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1)            51          dense_14[0][0]
# ==================================================================================================
# Total params: 1,203,621
# Trainable params: 1,203,549
# Non-trainable params: 72
# __________________________________________________________________________________________________

# %%
batch_size = 1
v_generator = resec_Generator(map_df[:-50], batch_size=batch_size)
validation_generator = resec_Generator(map_df[-50:-30], batch_size=batch_size)

# %%
history = model.fit_generator(v_generator,
                              epochs=4, validation_data=validation_generator)
# Out:
# Epoch 1/4
# 132/132 [==============================] - 500s 4s/step - loss: 0.6931 - binary_accuracy: 0.5682 - val_loss: 0.6936 - val_binary_accuracy: 0.6000
# Epoch 2/4
# 132/132 [==============================] - 462s 4s/step - loss: 0.6988 - binary_accuracy: 0.4394 - val_loss: 0.6961 - val_binary_accuracy: 0.5500
# Epoch 3/4
# 132/132 [==============================] - 459s 3s/step - loss: 0.6958 - binary_accuracy: 0.4773 - val_loss: 0.6943 - val_binary_accuracy: 0.5000
# Epoch 4/4
# 132/132 [==============================] - 465s 4s/step - loss: 0.6947 - binary_accuracy: 0.5303 - val_loss: 0.6874 - val_binary_accuracy: 0.6000

# %%
history = model.fit_generator(v_generator,
                              epochs=10, validation_data=validation_generator)
# Out:
# Epoch 1/10
# 132/132 [==============================] - 461s 3s/step - loss: 0.6957 - binary_accuracy: 0.4848 - val_loss: 0.6887 - val_binary_accuracy: 0.6000
# Epoch 2/10
# 132/132 [==============================] - 461s 3s/step - loss: 0.6931 - binary_accuracy: 0.5152 - val_loss: 0.6898 - val_binary_accuracy: 0.6000
# Epoch 3/10
# 132/132 [==============================] - 463s 4s/step - loss: 0.6910 - binary_accuracy: 0.5152 - val_loss: 0.6889 - val_binary_accuracy: 0.5500
# Epoch 4/10
# 132/132 [==============================] - 458s 3s/step - loss: 0.6894 - binary_accuracy: 0.5455 - val_loss: 0.6910 - val_binary_accuracy: 0.5500
# Epoch 5/10
# 132/132 [==============================] - 458s 3s/step - loss: 0.6863 - binary_accuracy: 0.5909 - val_loss: 0.6853 - val_binary_accuracy: 0.6000
# Epoch 6/10
# 132/132 [==============================] - 456s 3s/step - loss: 0.6799 - binary_accuracy: 0.6061 - val_loss: 0.6859 - val_binary_accuracy: 0.6500
# Epoch 7/10
# 132/132 [==============================] - 462s 3s/step - loss: 0.6822 - binary_accuracy: 0.5606 - val_loss: 0.6816 - val_binary_accuracy: 0.7500
# Epoch 8/10
# 132/132 [==============================] - 461s 3s/step - loss: 0.6842 - binary_accuracy: 0.5606 - val_loss: 0.6722 - val_binary_accuracy: 0.6000
# Epoch 9/10
# 132/132 [==============================] - 454s 3s/step - loss: 0.6854 - binary_accuracy: 0.5455 - val_loss: 0.6642 - val_binary_accuracy: 0.6000
# Epoch 10/10
# 132/132 [==============================] - 458s 3s/step - loss: 0.6813 - binary_accuracy: 0.5227 - val_loss: 0.6670 - val_binary_accuracy: 0.6000

# %%
model.save('resec_model_extend.h5')

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_binary_accuracy', 'loss', 'binary_accuracy'])
