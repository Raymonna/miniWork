# %%
import os
import glob
#import tqdm
import numpy as np
#import pandas as pd
import multiprocessing
import pydicom as dicom
import nibabel as nib
#from keras import utils as kutils
from matplotlib import pyplot as plt

def load_image(label_fpath, transpose=False):
    #encode_name = label_fpath[-39: -7]
    label_data = nib.load(label_fpath)
    label_array = label_data.get_fdata()
    if transpose:
        label_array = np.transpose(label_array, axes=(2, 1, 0))
    return  label_array#, encode_name

# %%
import os
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
gpu_options = tf.GPUOptions(allow_growth=True)
sess_config = tf.ConfigProto(gpu_options=gpu_options)
tf.keras.backend.set_session(tf.Session(config=sess_config))

# %%
cd ..
# Out:
# /home/u/wartytw

# %%
import pandas as pd
info = pd.read_csv('/data2/pancreas/Nifti_data/data_list.csv')
image_path = "/data2/pancreas/Nifti_data/image"
label_path = "/data2/pancreas/Nifti_data/label"

resec_train = np.load("resec_train.npy")
resec_val = np.load("resec_val.npy")
y_train = np.load("y_train.npy")
y_val = np.load("y_val.npy")

shape_tumor = np.load("box_tumor.npy")
tumor_shape = np.load("box_tumor.npy")

resec = np.concatenate([resec_train, resec_val], axis = 0)
y = np.concatenate([y_train, y_val], axis = 0)

# %%
#New
def extract_cube(r, img):#cube 200, 85, 40 ;; ranges = [xmin, xmax, ymin, ymax, zmin, zmax]
    img_tmp = np.zeros((200, 85, 40))
    img_tmp[:int(r[1]-r[0]), :int(r[3]-r[2]), :int(r[5]-r[4])] = img[int(r[0]):int(r[1]), int(r[2]):int(r[3]), int(r[4]):int(r[5])]
    return img_tmp


def masking(label, img):
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if label[i, j] == 0 or label[i, j] == 1:
                img[i, j] = 0
    return img

# %%
import pandas as pd
map_df = pd.DataFrame(data={'resec_name': resec, 'shape': np.array(range(len(resec))), 'target':y.reshape(len(resec))})

# %%
from keras.models import Model#, load_model
from keras import layers as klayers
from keras.optimizers import Adam
from keras import utils as kutils
from keras import backend as K
from keras.callbacks import ModelCheckpoint



from keras.layers import Conv3D, MaxPool3D, Flatten, Dense
from keras.layers import Dropout, Input, BatchNormalization
from sklearn.metrics import confusion_matrix, accuracy_score
#from plotly.offline import iplot, init_notebook_mode
from keras.losses import categorical_crossentropy
from keras.optimizers import Adadelta
#import plotly.graph_objs as go
from matplotlib.pyplot import cm
from keras.models import Model
import numpy as np
import keras
import h5py

#init_notebook_mode(connected=True)
# %matplotlib inline


from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, multiply, concatenate,  MaxPool2D, Reshape
# from keras.layers import BatchNormalization, Activation, Embedding, ZeroPadding2D, Lambda
from keras.layers.advanced_activations import LeakyReLU, ReLU
from keras.layers.convolutional import UpSampling2D, Conv2D, Conv1D
from keras.models import Sequential, Model
from keras.optimizers import Adam, SGD
from keras.utils import to_categorical
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM, TimeDistributed, RepeatVector, Reshape
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
from keras.utils import to_categorical
from scipy import ndimage
class resec_Generator1(kutils.Sequence):
    'Generates data for Keras'
    def __init__(self, mapping_df, batch_size, shuffle=True):
        'Initialization'
        self.mapping_df = mapping_df
        self.data_num   = mapping_df.shape[0]
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(self.data_num / self.batch_size))


    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        #print("enter0")
        batch_mapping_df = \
            self.mapping_df.iloc[index*self.batch_size: (index+1)*self.batch_size]

        # Generate data
        X, y = self.__data_generation(batch_mapping_df)
        return X, y


    def on_epoch_end(self):
        'Updates indexes after each epoch'
        if self.shuffle:
            self.mapping_df = self.mapping_df.sample(frac=1).reset_index(drop=True)
            
    def __data_generation(self, batch_mapping_df):
        'Generates data containing batch_size samples' 
        # Initialization
        X = np.zeros((  self.batch_size, 200, 85, 40, 1)) 
#         x1 = np.zeros((self.batch_size, 1))
#         x2 = np.zeros((self.batch_size, 6))
        x3 = np.zeros((self.batch_size, 6))
        y = np.zeros((self.batch_size))

        # Generate data
        cnt = 0
        
        for i, row in batch_mapping_df.iterrows():
            #img = extract_cube(shape_tumor[row['shape']], load_image(os.path.join(image_path, "IM_"+row['resec_name']+".nii.gz")))
            encode = row['resec_name']
            volume_image = load_image(os.path.join(image_path, "IM_"+encode+".nii.gz"))
            label = load_image(os.path.join(label_path, "LB_"+encode+".nii.gz"))
            volume_image1 = extract_cube(shape_tumor[row['shape'], :], volume_image) 
            label1 = extract_cube(shape_tumor[row['shape'], :], label) 
            num_slice = volume_image1.shape[2]
            for _z in range(0, num_slice):
                label11 = ndimage.binary_dilation(label1[:, :, _z]).astype(label1[:, :, _z].dtype)
                volume_image1[..., _z] = masking(label11, volume_image1[..., _z])
                del label11

            #print(encode)
            X[ cnt, :, :, :, 0] = volume_image1
#             x1[cnt, :] = size[row['shape']]
#             x2[cnt, :] = shape[row['shape'], :]
            x3[cnt, :] = tumor_shape[row['shape'], :]
            del volume_image1, label1, volume_image, label
            #img = clip_img(load_image(os.path.join(image_path, "IM_"+row['resec_name']+".nii.gz")))
            #print("resec_name =", row['resec_name'])
#             for j in range(40):
#                 #print("img shape =", img.shape)
#                 #print("j =", j)
#                 X[j][cnt, :, :, :, 0] = extract_cube(img, j)
            y[cnt] = row['target']

#             position = extract_position(row['ref_idx'], row['point_idx'])
#             tmp_cube = extract_cube(position, row['ref_idx'])
#             if (tmp_cube.shape == (19, 19, 19)):
#                 X[cnt, :, :, :, 0] = extract_cube(position, row['ref_idx'])
#             else:
#                 X[cnt, :, :, :, 0] = np.zeros((19, 19, 19))
#             y_idx = row['y_idx']
#             radius = ref[row['ref_idx']][row['point_idx'], 3]
#             y1[cnt, y_idx] = 1
#             y2[cnt, 0] = radius
            cnt += 1
        #print(X[5])
        return [X, x3], y

# for name in resec:
#     img = load_image(os.path.join(image_path, "IM_"+name+".nii.gz"))

# %%
from keras import metrics
tmp_x = Input(( 200, 85, 40, 1))
x = Conv3D(filters=32, dilation_rate=1, kernel_size=(3, 3, 3),kernel_initializer = keras.initializers.he_normal(seed=None), activation='relu')(tmp_x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = MaxPool3D()(x)

x = Conv3D(filters=16, dilation_rate=1, kernel_size=(3, 3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = MaxPool3D()(x)

x = Conv3D(filters=8, dilation_rate=1, kernel_size=(3, 3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPool3D()(x)





# x = Conv3D(filters=4, dilation_rate=1, kernel_size=(3, 3, 3), activation='relu')(x)
# x = BatchNormalization()(x)
# x = MaxPool3D()(x)


x = Flatten()(x)
x = Dense(units=200, kernel_initializer = keras.initializers.he_normal(seed=None), activation='elu')(x)
x = Dense(units=100, activation='selu')(x)
x = Dense(units=10, activation='relu')(x)


# tmp_a = Input((1,))
# a = Dense(5, activation='elu')(tmp_a)
# a = Dense(2, activation='relu')(a)
# a = Dense(1,kernel_initializer = keras.initializers.he_normal(seed=None),  activation='relu')(a)

# tmp_b = Input((6,))
# b = Dense(10, activation='selu')(tmp_b)
# b = Dense(20, activation='selu')(b)
# b = Dense(10, activation='elu')(b)
# b = Dense(5,kernel_initializer = keras.initializers.he_normal(seed=None), activation='relu' )(b)
# b = Dense(3, activation='relu')(b)


tmp_c = Input((6,))
c = Dense(6,kernel_initializer = keras.initializers.he_normal(seed=None),  activation='selu')(tmp_c)
c = Dense(10, activation='elu')(c)
c = Dense(5,activation='relu' )(c)
c = Dense(3, activation='relu')(c)

x = concatenate([x, c], axis = 1)
x = Dense(1, activation='sigmoid')(x)





model = Model(inputs=[tmp_x,  tmp_c], outputs=x)
adam_lr = 0.0003
adam_beta_1 = 0.5
model.compile(optimizer=Adam(lr=adam_lr, beta_1=adam_beta_1),
              loss='binary_crossentropy', metrics = [metrics.binary_accuracy])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 200, 85, 40,  0
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 198, 83, 38,  896         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 198, 83, 38,  128         conv3d_11[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 198, 83, 38,  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_11 (MaxPooling3D) (None, 99, 41, 19, 3 0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 97, 39, 17, 1 13840       max_pooling3d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 97, 39, 17, 1 64          conv3d_12[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 97, 39, 17, 1 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_12 (MaxPooling3D) (None, 48, 19, 8, 16 0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 46, 17, 6, 8) 3464        max_pooling3d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 46, 17, 6, 8) 32          conv3d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_13 (MaxPooling3D) (None, 23, 8, 3, 8)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# input_7 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 4416)         0           max_pooling3d_13[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 6)            42          input_7[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 200)          883400      flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 10)           70          dense_20[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 100)          20100       dense_17[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 5)            55          dense_21[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 10)           1010        dense_18[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 3)            18          dense_22[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 13)           0           dense_19[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            14          concatenate_3[0][0]
# ==================================================================================================
# Total params: 923,133
# Trainable params: 923,021
# Non-trainable params: 112
# __________________________________________________________________________________________________

# %%
batch_size = 1
v_generator = resec_Generator1(map_df[:-20], batch_size=batch_size)
validation_generator = resec_Generator1(map_df[-20:], batch_size=batch_size)

# %%
history = model.fit_generator(v_generator,
                              epochs=100, validation_data=validation_generator)
# Out:
# Epoch 1/100
# 117/117 [==============================] - 166s 1s/step - loss: 1.6204 - binary_accuracy: 0.4872 - val_loss: 1.5324 - val_binary_accuracy: 0.5000
# Epoch 2/100
# 117/117 [==============================] - 157s 1s/step - loss: 1.3011 - binary_accuracy: 0.5556 - val_loss: 1.0622 - val_binary_accuracy: 0.5500
# Epoch 3/100
# 117/117 [==============================] - 156s 1s/step - loss: 1.1191 - binary_accuracy: 0.5299 - val_loss: 1.0194 - val_binary_accuracy: 0.5500
# Epoch 4/100
# 117/117 [==============================] - 159s 1s/step - loss: 0.9904 - binary_accuracy: 0.5641 - val_loss: 1.1198 - val_binary_accuracy: 0.4500
# Epoch 5/100
# 117/117 [==============================] - 154s 1s/step - loss: 0.9197 - binary_accuracy: 0.5641 - val_loss: 1.0194 - val_binary_accuracy: 0.6000
# Epoch 6/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.8820 - binary_accuracy: 0.6239 - val_loss: 0.9533 - val_binary_accuracy: 0.6000
# Epoch 7/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.8532 - binary_accuracy: 0.5812 - val_loss: 0.9554 - val_binary_accuracy: 0.6000
# Epoch 8/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.8441 - binary_accuracy: 0.5726 - val_loss: 0.9809 - val_binary_accuracy: 0.5000
# Epoch 9/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.7864 - binary_accuracy: 0.6068 - val_loss: 0.9682 - val_binary_accuracy: 0.5000
# Epoch 11/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.7904 - binary_accuracy: 0.5812 - val_loss: 0.8642 - val_binary_accuracy: 0.6000
# Epoch 12/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.7784 - binary_accuracy: 0.5897 - val_loss: 0.8713 - val_binary_accuracy: 0.5500
# Epoch 13/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.7828 - binary_accuracy: 0.5556 - val_loss: 0.8782 - val_binary_accuracy: 0.5000
# Epoch 14/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.7381 - binary_accuracy: 0.5812 - val_loss: 0.8108 - val_binary_accuracy: 0.6000
# Epoch 15/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.7397 - binary_accuracy: 0.5641 - val_loss: 0.8184 - val_binary_accuracy: 0.5000
# Epoch 16/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.7239 - binary_accuracy: 0.5897 - val_loss: 0.9041 - val_binary_accuracy: 0.4500
# Epoch 17/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.7189 - binary_accuracy: 0.5470 - val_loss: 0.7844 - val_binary_accuracy: 0.5500
# Epoch 18/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.7142 - binary_accuracy: 0.5983 - val_loss: 0.7724 - val_binary_accuracy: 0.5500
# Epoch 19/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.7042 - binary_accuracy: 0.6239 - val_loss: 0.7742 - val_binary_accuracy: 0.5500
# Epoch 20/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.6939 - binary_accuracy: 0.5897 - val_loss: 0.8919 - val_binary_accuracy: 0.4500
# Epoch 21/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.6881 - binary_accuracy: 0.5897 - val_loss: 0.7792 - val_binary_accuracy: 0.5000
# Epoch 22/100
# 117/117 [==============================] - 154s 1s/step - loss: 0.6743 - binary_accuracy: 0.5726 - val_loss: 0.7565 - val_binary_accuracy: 0.5500
# Epoch 23/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6853 - binary_accuracy: 0.5983 - val_loss: 0.7458 - val_binary_accuracy: 0.6000
# Epoch 24/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.6819 - binary_accuracy: 0.5897 - val_loss: 0.7432 - val_binary_accuracy: 0.5500
# Epoch 25/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.6815 - binary_accuracy: 0.6325 - val_loss: 0.7522 - val_binary_accuracy: 0.5500
# Epoch 26/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.6886 - binary_accuracy: 0.5897 - val_loss: 0.7444 - val_binary_accuracy: 0.5500
# Epoch 27/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.6677 - binary_accuracy: 0.6410 - val_loss: 0.7358 - val_binary_accuracy: 0.5500
# Epoch 28/100
# 117/117 [==============================] - 154s 1s/step - loss: 0.6621 - binary_accuracy: 0.6410 - val_loss: 0.7309 - val_binary_accuracy: 0.5500
# Epoch 29/100
# 117/117 [==============================] - 161s 1s/step - loss: 0.6602 - binary_accuracy: 0.6154 - val_loss: 0.7923 - val_binary_accuracy: 0.4500
# Epoch 30/100
# 117/117 [==============================] - 153s 1s/step - loss: 0.6887 - binary_accuracy: 0.5812 - val_loss: 0.7687 - val_binary_accuracy: 0.4500
# Epoch 31/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.6924 - binary_accuracy: 0.5983 - val_loss: 0.7215 - val_binary_accuracy: 0.5000
# Epoch 32/100
# 117/117 [==============================] - 159s 1s/step - loss: 0.6789 - binary_accuracy: 0.5812 - val_loss: 0.7214 - val_binary_accuracy: 0.5500
# Epoch 33/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.6680 - binary_accuracy: 0.6325 - val_loss: 0.7533 - val_binary_accuracy: 0.4500
# Epoch 34/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6676 - binary_accuracy: 0.5812 - val_loss: 0.7266 - val_binary_accuracy: 0.6000
# Epoch 35/100
#  86/117 [=====================>........] - ETA: 35s - loss: 0.7220 - binary_accuracy: 0.5465
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 117/117 [==============================] - 158s 1s/step - loss: 0.6652 - binary_accuracy: 0.5983 - val_loss: 0.7053 - val_binary_accuracy: 0.5000
# Epoch 72/100
# 117/117 [==============================] - 154s 1s/step - loss: 0.6489 - binary_accuracy: 0.5812 - val_loss: 0.7290 - val_binary_accuracy: 0.4500
# Epoch 73/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6122 - binary_accuracy: 0.6581 - val_loss: 0.9073 - val_binary_accuracy: 0.5500
# Epoch 74/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.6455 - binary_accuracy: 0.6325 - val_loss: 0.8086 - val_binary_accuracy: 0.5500
# Epoch 75/100
# 117/117 [==============================] - 159s 1s/step - loss: 0.6469 - binary_accuracy: 0.5897 - val_loss: 0.7582 - val_binary_accuracy: 0.5500
# Epoch 76/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.6479 - binary_accuracy: 0.6068 - val_loss: 0.7555 - val_binary_accuracy: 0.5500
# Epoch 77/100
# 117/117 [==============================] - 155s 1s/step - loss: 0.6623 - binary_accuracy: 0.6410 - val_loss: 0.7164 - val_binary_accuracy: 0.4500
# Epoch 78/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.6551 - binary_accuracy: 0.5983 - val_loss: 0.7118 - val_binary_accuracy: 0.5000
# Epoch 79/100
# 117/117 [==============================] - 153s 1s/step - loss: 0.6542 - binary_accuracy: 0.5983 - val_loss: 0.7549 - val_binary_accuracy: 0.5500
# Epoch 80/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6597 - binary_accuracy: 0.6154 - val_loss: 0.7139 - val_binary_accuracy: 0.4500
# Epoch 81/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6540 - binary_accuracy: 0.6410 - val_loss: 0.7080 - val_binary_accuracy: 0.5500
# Epoch 82/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6593 - binary_accuracy: 0.5897 - val_loss: 0.7061 - val_binary_accuracy: 0.5500
# Epoch 83/100
# 117/117 [==============================] - 153s 1s/step - loss: 0.6512 - binary_accuracy: 0.6410 - val_loss: 0.7096 - val_binary_accuracy: 0.5500
# Epoch 84/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6384 - binary_accuracy: 0.6410 - val_loss: 0.7324 - val_binary_accuracy: 0.5000
# Epoch 85/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6621 - binary_accuracy: 0.5641 - val_loss: 0.7132 - val_binary_accuracy: 0.4500
# Epoch 86/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.6551 - binary_accuracy: 0.6154 - val_loss: 0.7114 - val_binary_accuracy: 0.4500
# Epoch 87/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6533 - binary_accuracy: 0.6239 - val_loss: 0.7040 - val_binary_accuracy: 0.5000
# Epoch 88/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6449 - binary_accuracy: 0.6239 - val_loss: 0.7173 - val_binary_accuracy: 0.5000
# Epoch 89/100
# 117/117 [==============================] - 154s 1s/step - loss: 0.6643 - binary_accuracy: 0.5726 - val_loss: 0.7122 - val_binary_accuracy: 0.5000
# Epoch 90/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.6324 - binary_accuracy: 0.6496 - val_loss: 0.7003 - val_binary_accuracy: 0.5000
# Epoch 91/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.6398 - binary_accuracy: 0.6410 - val_loss: 0.7291 - val_binary_accuracy: 0.5500
# Epoch 92/100
# 117/117 [==============================] - 157s 1s/step - loss: 0.6528 - binary_accuracy: 0.6068 - val_loss: 0.7021 - val_binary_accuracy: 0.5000
# Epoch 93/100
# 117/117 [==============================] - 156s 1s/step - loss: 0.6531 - binary_accuracy: 0.6154 - val_loss: 0.7428 - val_binary_accuracy: 0.5000
# Epoch 94/100
# 117/117 [==============================] - 158s 1s/step - loss: 0.6393 - binary_accuracy: 0.6068 - val_loss: 0.7392 - val_binary_accuracy: 0.5000
# Epoch 95/100
# 117/117 [==============================] - 153s 1s/step - loss: 0.6661 - binary_accuracy: 0.5470 - val_loss: 0.7171 - val_binary_accuracy: 0.5000
# Epoch 96/100
# 117/117 [==============================] - 159s 1s/step - loss: 0.6541 - binary_accuracy: 0.5812 - val_loss: 0.7212 - val_binary_accuracy: 0.5000
# Epoch 97/100
#  32/117 [=======>......................] - ETA: 1:22 - loss: 0.7067 - binary_accuracy: 0.5938
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_binary_accuracy', 'loss', 'binary_accuracy'])

# %%
history = model.fit_generator(v_generator,
                              epochs=100, validation_data=validation_generator)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 81s 1s/step - loss: 0.6832 - binary_accuracy: 0.6441 - val_loss: 0.6900 - val_binary_accuracy: 0.5500
# Epoch 2/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6826 - binary_accuracy: 0.6441 - val_loss: 0.6899 - val_binary_accuracy: 0.5500
# Epoch 3/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6821 - binary_accuracy: 0.6441 - val_loss: 0.6898 - val_binary_accuracy: 0.5500
# Epoch 4/100
# 59/59 [==============================] - 79s 1s/step - loss: 0.6815 - binary_accuracy: 0.6441 - val_loss: 0.6897 - val_binary_accuracy: 0.5500
# Epoch 5/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6810 - binary_accuracy: 0.6441 - val_loss: 0.6895 - val_binary_accuracy: 0.5500
# Epoch 6/100
# 59/59 [==============================] - 78s 1s/step - loss: 0.6805 - binary_accuracy: 0.6441 - val_loss: 0.6894 - val_binary_accuracy: 0.5500
# Epoch 7/100
# 59/59 [==============================] - 78s 1s/step - loss: 0.6800 - binary_accuracy: 0.6441 - val_loss: 0.6893 - val_binary_accuracy: 0.5500
# Epoch 8/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6795 - binary_accuracy: 0.6441 - val_loss: 0.6892 - val_binary_accuracy: 0.5500
# Epoch 9/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6790 - binary_accuracy: 0.6441 - val_loss: 0.6891 - val_binary_accuracy: 0.5500
# Epoch 10/100
# 59/59 [==============================] - 70s 1s/step - loss: 0.6785 - binary_accuracy: 0.6441 - val_loss: 0.6890 - val_binary_accuracy: 0.5500
# Epoch 11/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6780 - binary_accuracy: 0.6441 - val_loss: 0.6890 - val_binary_accuracy: 0.5500
# Epoch 12/100
# 59/59 [==============================] - 81s 1s/step - loss: 0.6776 - binary_accuracy: 0.6441 - val_loss: 0.6889 - val_binary_accuracy: 0.5500
# Epoch 13/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6771 - binary_accuracy: 0.6441 - val_loss: 0.6888 - val_binary_accuracy: 0.5500
# Epoch 14/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6767 - binary_accuracy: 0.6441 - val_loss: 0.6887 - val_binary_accuracy: 0.5500
# Epoch 15/100
# 59/59 [==============================] - 71s 1s/step - loss: 0.6762 - binary_accuracy: 0.6441 - val_loss: 0.6887 - val_binary_accuracy: 0.5500
# Epoch 16/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6758 - binary_accuracy: 0.6441 - val_loss: 0.6886 - val_binary_accuracy: 0.5500
# Epoch 17/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6753 - binary_accuracy: 0.6441 - val_loss: 0.6885 - val_binary_accuracy: 0.5500
# Epoch 18/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6749 - binary_accuracy: 0.6441 - val_loss: 0.6885 - val_binary_accuracy: 0.5500
# Epoch 19/100
# 59/59 [==============================] - 70s 1s/step - loss: 0.6745 - binary_accuracy: 0.6441 - val_loss: 0.6884 - val_binary_accuracy: 0.5500
# Epoch 20/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6741 - binary_accuracy: 0.6441 - val_loss: 0.6884 - val_binary_accuracy: 0.5500
# Epoch 21/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6737 - binary_accuracy: 0.6441 - val_loss: 0.6884 - val_binary_accuracy: 0.5500
# Epoch 22/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6733 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 23/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6729 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 24/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6725 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 25/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6722 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 26/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6718 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 27/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6715 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 28/100
# 59/59 [==============================] - 68s 1s/step - loss: 0.6711 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 29/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6707 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 30/100
# 59/59 [==============================] - 79s 1s/step - loss: 0.6704 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 31/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6697 - binary_accuracy: 0.6441 - val_loss: 0.6881 - val_binary_accuracy: 0.5500
# Epoch 33/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6694 - binary_accuracy: 0.6441 - val_loss: 0.6881 - val_binary_accuracy: 0.5500
# Epoch 34/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6691 - binary_accuracy: 0.6441 - val_loss: 0.6881 - val_binary_accuracy: 0.5500
# Epoch 35/100
# 59/59 [==============================] - 79s 1s/step - loss: 0.6688 - binary_accuracy: 0.6441 - val_loss: 0.6881 - val_binary_accuracy: 0.5500
# Epoch 36/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6685 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 37/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6682 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 38/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6679 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 39/100
# 59/59 [==============================] - 81s 1s/step - loss: 0.6676 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 40/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6673 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 41/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6670 - binary_accuracy: 0.6441 - val_loss: 0.6882 - val_binary_accuracy: 0.5500
# Epoch 42/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6668 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 43/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6665 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 44/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6662 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 45/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6659 - binary_accuracy: 0.6441 - val_loss: 0.6883 - val_binary_accuracy: 0.5500
# Epoch 46/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6657 - binary_accuracy: 0.6441 - val_loss: 0.6884 - val_binary_accuracy: 0.5500
# Epoch 47/100
# 59/59 [==============================] - 71s 1s/step - loss: 0.6654 - binary_accuracy: 0.6441 - val_loss: 0.6884 - val_binary_accuracy: 0.5500
# Epoch 48/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6652 - binary_accuracy: 0.6441 - val_loss: 0.6884 - val_binary_accuracy: 0.5500
# Epoch 49/100
# 59/59 [==============================] - 79s 1s/step - loss: 0.6649 - binary_accuracy: 0.6441 - val_loss: 0.6885 - val_binary_accuracy: 0.5500
# Epoch 50/100
# 59/59 [==============================] - 70s 1s/step - loss: 0.6647 - binary_accuracy: 0.6441 - val_loss: 0.6885 - val_binary_accuracy: 0.5500
# Epoch 51/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6645 - binary_accuracy: 0.6441 - val_loss: 0.6885 - val_binary_accuracy: 0.5500
# Epoch 52/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6643 - binary_accuracy: 0.6441 - val_loss: 0.6886 - val_binary_accuracy: 0.5500
# Epoch 53/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6640 - binary_accuracy: 0.6441 - val_loss: 0.6886 - val_binary_accuracy: 0.5500
# Epoch 54/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6638 - binary_accuracy: 0.6441 - val_loss: 0.6887 - val_binary_accuracy: 0.5500
# Epoch 55/100
# 59/59 [==============================] - 78s 1s/step - loss: 0.6636 - binary_accuracy: 0.6441 - val_loss: 0.6887 - val_binary_accuracy: 0.5500
# Epoch 56/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6633 - binary_accuracy: 0.6441 - val_loss: 0.6888 - val_binary_accuracy: 0.5500
# Epoch 57/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6631 - binary_accuracy: 0.6441 - val_loss: 0.6888 - val_binary_accuracy: 0.5500
# Epoch 58/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6629 - binary_accuracy: 0.6441 - val_loss: 0.6889 - val_binary_accuracy: 0.5500
# Epoch 59/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6627 - binary_accuracy: 0.6441 - val_loss: 0.6889 - val_binary_accuracy: 0.5500
# Epoch 60/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6625 - binary_accuracy: 0.6441 - val_loss: 0.6890 - val_binary_accuracy: 0.5500
# Epoch 61/100
# 59/59 [==============================] - 70s 1s/step - loss: 0.6623 - binary_accuracy: 0.6441 - val_loss: 0.6890 - val_binary_accuracy: 0.5500
# Epoch 62/100
# 59/59 [==============================] - 81s 1s/step - loss: 0.6621 - binary_accuracy: 0.6441 - val_loss: 0.6891 - val_binary_accuracy: 0.5500
# Epoch 63/100
# 59/59 [==============================] - 78s 1s/step - loss: 0.6619 - binary_accuracy: 0.6441 - val_loss: 0.6892 - val_binary_accuracy: 0.5500
# Epoch 64/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6618 - binary_accuracy: 0.6441 - val_loss: 0.6892 - val_binary_accuracy: 0.5500
# Epoch 65/100
# 59/59 [==============================] - 69s 1s/step - loss: 0.6616 - binary_accuracy: 0.6441 - val_loss: 0.6893 - val_binary_accuracy: 0.5500
# Epoch 66/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6614 - binary_accuracy: 0.6441 - val_loss: 0.6893 - val_binary_accuracy: 0.5500
# Epoch 67/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6612 - binary_accuracy: 0.6441 - val_loss: 0.6894 - val_binary_accuracy: 0.5500
# Epoch 68/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6610 - binary_accuracy: 0.6441 - val_loss: 0.6895 - val_binary_accuracy: 0.5500
# Epoch 69/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6609 - binary_accuracy: 0.6441 - val_loss: 0.6895 - val_binary_accuracy: 0.5500
# Epoch 70/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6607 - binary_accuracy: 0.6441 - val_loss: 0.6896 - val_binary_accuracy: 0.5500
# Epoch 71/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6605 - binary_accuracy: 0.6441 - val_loss: 0.6896 - val_binary_accuracy: 0.5500
# Epoch 72/100
# 59/59 [==============================] - 78s 1s/step - loss: 0.6604 - binary_accuracy: 0.6441 - val_loss: 0.6897 - val_binary_accuracy: 0.5500
# Epoch 73/100
# 59/59 [==============================] - 75s 1s/step - loss: 0.6602 - binary_accuracy: 0.6441 - val_loss: 0.6898 - val_binary_accuracy: 0.5500
# Epoch 74/100
# 59/59 [==============================] - 69s 1s/step - loss: 0.6600 - binary_accuracy: 0.6441 - val_loss: 0.6898 - val_binary_accuracy: 0.5500
# Epoch 75/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6599 - binary_accuracy: 0.6441 - val_loss: 0.6899 - val_binary_accuracy: 0.5500
# Epoch 76/100
# 59/59 [==============================] - 70s 1s/step - loss: 0.6597 - binary_accuracy: 0.6441 - val_loss: 0.6900 - val_binary_accuracy: 0.5500
# Epoch 77/100
# 59/59 [==============================] - 78s 1s/step - loss: 0.6596 - binary_accuracy: 0.6441 - val_loss: 0.6901 - val_binary_accuracy: 0.5500
# Epoch 78/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6594 - binary_accuracy: 0.6441 - val_loss: 0.6901 - val_binary_accuracy: 0.5500
# Epoch 79/100
# 59/59 [==============================] - 81s 1s/step - loss: 0.6593 - binary_accuracy: 0.6441 - val_loss: 0.6902 - val_binary_accuracy: 0.5500
# Epoch 80/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6591 - binary_accuracy: 0.6441 - val_loss: 0.6903 - val_binary_accuracy: 0.5500
# Epoch 81/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6590 - binary_accuracy: 0.6441 - val_loss: 0.6903 - val_binary_accuracy: 0.5500
# Epoch 82/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6589 - binary_accuracy: 0.6441 - val_loss: 0.6904 - val_binary_accuracy: 0.5500
# Epoch 83/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6588 - binary_accuracy: 0.6441 - val_loss: 0.6905 - val_binary_accuracy: 0.5500
# Epoch 84/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6586 - binary_accuracy: 0.6441 - val_loss: 0.6906 - val_binary_accuracy: 0.5500
# Epoch 85/100
# 59/59 [==============================] - 70s 1s/step - loss: 0.6585 - binary_accuracy: 0.6441 - val_loss: 0.6906 - val_binary_accuracy: 0.5500
# Epoch 86/100
# 59/59 [==============================] - 71s 1s/step - loss: 0.6584 - binary_accuracy: 0.6441 - val_loss: 0.6907 - val_binary_accuracy: 0.5500
# Epoch 87/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6582 - binary_accuracy: 0.6441 - val_loss: 0.6908 - val_binary_accuracy: 0.5500
# Epoch 88/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6581 - binary_accuracy: 0.6441 - val_loss: 0.6909 - val_binary_accuracy: 0.5500
# Epoch 89/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6580 - binary_accuracy: 0.6441 - val_loss: 0.6909 - val_binary_accuracy: 0.5500
# Epoch 90/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6578 - binary_accuracy: 0.6441 - val_loss: 0.6910 - val_binary_accuracy: 0.5500
# Epoch 91/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6577 - binary_accuracy: 0.6441 - val_loss: 0.6911 - val_binary_accuracy: 0.5500
# Epoch 92/100
# 59/59 [==============================] - 66s 1s/step - loss: 0.6576 - binary_accuracy: 0.6441 - val_loss: 0.6912 - val_binary_accuracy: 0.5500
# Epoch 93/100
# 59/59 [==============================] - 74s 1s/step - loss: 0.6575 - binary_accuracy: 0.6441 - val_loss: 0.6913 - val_binary_accuracy: 0.5500
# Epoch 94/100
# 59/59 [==============================] - 72s 1s/step - loss: 0.6574 - binary_accuracy: 0.6441 - val_loss: 0.6914 - val_binary_accuracy: 0.5500
# Epoch 95/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6573 - binary_accuracy: 0.6441 - val_loss: 0.6914 - val_binary_accuracy: 0.5500
# Epoch 96/100
# 59/59 [==============================] - 76s 1s/step - loss: 0.6572 - binary_accuracy: 0.6441 - val_loss: 0.6915 - val_binary_accuracy: 0.5500
# Epoch 97/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6571 - binary_accuracy: 0.6441 - val_loss: 0.6916 - val_binary_accuracy: 0.5500
# Epoch 98/100
# 59/59 [==============================] - 71s 1s/step - loss: 0.6570 - binary_accuracy: 0.6441 - val_loss: 0.6917 - val_binary_accuracy: 0.5500
# Epoch 99/100
# 59/59 [==============================] - 77s 1s/step - loss: 0.6569 - binary_accuracy: 0.6441 - val_loss: 0.6917 - val_binary_accuracy: 0.5500
# Epoch 100/100
# 59/59 [==============================] - 73s 1s/step - loss: 0.6568 - binary_accuracy: 0.6441 - val_loss: 0.6918 - val_binary_accuracy: 0.5500
